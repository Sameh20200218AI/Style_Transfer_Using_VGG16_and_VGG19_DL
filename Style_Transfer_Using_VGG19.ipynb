# %%
# Import necessary libraries
import tensorflow as tf  # Import TensorFlow, an open-source machine learning framework
import numpy as np  # Import NumPy, a library for handling large multi-dimensional arrays and matrices
import matplotlib.pyplot as plt  # Import Matplotlib for creating visualizations like plots and graphs
import math  # Import Python's math library for mathematical functions
import time  # Import time library to measure the time for various operations

# Import VGG19 model and Keras Model API from TensorFlow
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input  # Import the VGG19 model architecture from Keras, and a preprocessing function for images

# Import the functions to load and process images
from tensorflow.keras.preprocessing.image import load_img, img_to_array  # Load images from files and convert them to NumPy arrays
from tensorflow.keras.models import Model  # Import the Keras Model class to build and manage neural network models

# Printing the imported libraries for verification
print("Libraries imported successfully: TensorFlow, NumPy, Matplotlib, math, time")
print("VGG19 and necessary Keras modules are ready for use.")
# Out:
# Libraries imported successfully: TensorFlow, NumPy, Matplotlib, math, time
# VGG19 and necessary Keras modules are ready for use.

# %%
# Function to load and process an image
def load_and_process_image(image_path):
    # Load the image from the given file path
    img = load_img(image_path)
    #print(f"Image loaded from {image_path}")

    # Convert the loaded image into a NumPy array (so that it can be fed into a neural network)
    img = img_to_array(img)
    #print(f"Image converted to NumPy array with shape: {img.shape}")

    # Preprocess the image to fit the input requirements of VGG19 (mean subtraction, etc.)
    img = preprocess_input(img)
    #print("Image preprocessed for VGG19 input.")

    # Expand the dimensions of the image array to include a batch dimension (VGG19 expects 4D input)
    img = np.expand_dims(img, axis=0)
    print(f"Image shape after adding batch dimension: {img.shape}")

    # Return the processed image ready for model input
    return img

# %%
# Function to deprocess the image (inverse of preprocessing)
def deprocess(img):
    # Perform the inverse of the preprocessing step: add the mean values back to each channel
    img[:, :, 0] += 103.939  # Add the mean value of the Red channel
    img[:, :, 1] += 116.779  # Add the mean value of the Green channel
    img[:, :, 2] += 123.68   # Add the mean value of the Blue channel
    #print("Mean values added back to each channel.")

    # Convert from RGB (as used in preprocessing) to BGR (as used by VGG19)
    img = img[:, :, ::-1]  # Reverse the channel order: RGB -> BGR
    #print("Converted image from RGB to BGR.")

    # Clip the pixel values to ensure they are within the valid range [0, 255], then convert to 'uint8'
    img = np.clip(img, 0, 255).astype('uint8')  # Ensures that pixel values are between 0 and 255 and of the correct type
    #print("Clipped and converted image to uint8.")

    # Return the deprocessed image
    return img

# %%
def display_image(image):
    # Remove batch dimension if present
    if len(image.shape) == 4:
        img = np.squeeze(image, axis=0)  # Remove the batch dimension
    else:
        img = image  # If no batch dimension exists, use the image directly

    # Deprocess the image (reverse the preprocessing)
    img = deprocess(img)

    # Display the image with Matplotlib
    plt.grid(False)  # Remove grid lines
    plt.xticks([])   # Remove x-axis ticks
    plt.yticks([])   # Remove y-axis ticks
    plt.imshow(img)  # Display the image

    return

# %%
# load content image
content_img_path = '/content/never give up.jfif'
content_img = load_and_process_image(content_img_path)
display_image(content_img)
# Out:
# Image shape after adding batch dimension: (1, 225, 225, 3)

# %%
# load style image
style_img_path = '/content/images.jfif'
style_img = load_and_process_image(style_img_path)
display_image(style_img)
# Out:
# Image shape after adding batch dimension: (1, 194, 260, 3)

# %%
# download the VGG19 model and initialise it
model = VGG19(
	include_top=False,
	weights='imagenet'
)
# set training to False
model.trainable = False

# Print details of different layers
model.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
# Define the content model by selecting a specific layer of the pre-trained VGG19 model
content_layer = 'block5_conv2'  # Set the layer we want to extract features from for content representation
print(f"Selected content layer: {content_layer}")

# Create a new model that outputs the feature map of the chosen layer
content_model = Model(
    inputs=model.input,  # Input to the model is the same as the original model input
    outputs=model.get_layer(content_layer).output  # Output of the new model is the feature map of the selected layer
)

# Print the summary of the content model to verify the architecture
content_model.summary()
# Out:
# Selected content layer: block5_conv2
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,304,768 (58.38 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 15,304,768 (58.38 MB)

# %%
# Define the style model by selecting multiple layers from the VGG19 model for style representation
style_layers = [
    'block1_conv1',  # Layer 1: The first convolutional layer from block 1 (captures fine-grained style features)
    'block3_conv1',  # Layer 2: The first convolutional layer from block 3 (captures medium-level style features)
    'block5_conv1'   # Layer 3: The first convolutional layer from block 5 (captures high-level style features)
]
print(f"Selected style layers: {style_layers}")

# Create a list of models, each extracting the feature map from a different style layer
style_models = [
    Model(inputs=model.input,  # Input to the model is the same as the original model input
          outputs=model.get_layer(layer).output)  # Output is the feature map from the selected style layer
    for layer in style_layers
]

# Printing the summaries of each style model to confirm their structure
for i, style_model in enumerate(style_models):
    print(f"Summary of style model {i+1} for layer {style_layers[i]}:")
    style_model.summary()
# Out:
# Selected style layers: ['block1_conv1', 'block3_conv1', 'block5_conv1']
# Summary of style model 1 for layer block1_conv1:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,792 (7.00 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 1,792 (7.00 KB)
# Summary of style model 2 for layer block3_conv1:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 555,328 (2.12 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 555,328 (2.12 MB)
# Summary of style model 3 for layer block5_conv1:
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,944,960 (49.38 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 12,944,960 (49.38 MB)

# %%
# Function to compute the content loss between the content and generated images
def content_loss(content, generated):
    # Get the activations (feature maps) for the content image from the content model
    a_C = content_model(content)
    print(f"Content activations shape: {a_C.shape}")  # Print the shape of the activations for content

    # Get the activations (feature maps) for the generated image from the content model
    a_G = content_model(generated)  # Compute activations for the generated image
    print(f"Generated activations shape: {a_G.shape}")  # Print the shape of the activations for generated image

    # Compute the mean squared error between the content activations and the generated activations
    loss = tf.reduce_mean(tf.square(a_C - a_G))  # This calculates the content loss
    print(f"Content loss: {loss.numpy()}")  # Print the computed content loss value

    # Return the content loss value
    return loss

# %%
# Function to compute the Gram matrix of a given tensor
def gram_matrix(A):
    # Get the number of channels in the input tensor (i.e., the depth of the feature map)
    channels = int(A.shape[-1])
    #print(f"Number of channels in the feature map: {channels}")

    # Reshape the tensor to have shape [batch_size * height * width, channels]
    # Flatten the spatial dimensions (height * width) while keeping the channels dimension
    a = tf.reshape(A, [-1, channels])
    #print(f"Reshaped tensor shape: {a.shape}")  # Print the shape after reshaping

    # Get the number of elements (pixels) in the reshaped tensor
    n = tf.shape(a)[0]
    #print(f"Number of elements (pixels) in the reshaped tensor: {n}")

    # Compute the Gram matrix by performing matrix multiplication
    # This captures the correlations between different channels
    gram = tf.matmul(a, a, transpose_a=True)
    #print(f"Gram matrix shape: {gram.shape}")  # Print the shape of the Gram matrix

    # Normalize the Gram matrix by dividing by the number of elements (pixels) in the flattened tensor
    return gram / tf.cast(n, tf.float32)  # Normalize by casting n to float32 to match the data type


# Calculate the weight for each style layer
weight_of_layer = 1. / len(style_models)  # The weight is the inverse of the number of style layers
print(f"Weight of each style layer: {weight_of_layer}")
# Out:
# Weight of each style layer: 0.3333333333333333

# %%
# Function to compute the style loss between the style and generated images
def style_cost(style, generated):
    # Initialize the total style loss (J_style) to 0
    J_style = 0
    #print("Initialized total style loss: J_style = 0")

    # Loop through each style model corresponding to the selected style layers
    for i, style_model in enumerate(style_models):
        #print(f"\nProcessing style model {i+1} for layer {style_layers[i]}")

        # Get the activations (feature maps) for the style image from the current style model
        a_S = style_model(style)
        #print(f"Shape of activations for style image (Layer {style_layers[i]}): {a_S.shape}")

        # Get the activations (feature maps) for the generated image from the current style model
        a_G = style_model(generated)
        #print(f"Shape of activations for generated image (Layer {style_layers[i]}): {a_G.shape}")

        # Compute the Gram matrix for both style and generated image activations
        GS = gram_matrix(a_S)
        GG = gram_matrix(a_G)
        #print(f"Gram matrix for style image (Layer {style_layers[i]}): {GS.shape}")
        #print(f"Gram matrix for generated image (Layer {style_layers[i]}): {GG.shape}")

        # Compute the style loss for this layer (mean squared error between the Gram matrices)
        content_cost = tf.reduce_mean(tf.square(GS - GG))
        print(f"Style loss for layer {style_layers[i]}: {content_cost.numpy()}")

        # Accumulate the style loss and weight it by the layer's contribution (weight_of_layer)
        J_style += content_cost * weight_of_layer
        print(f"Updated total style loss: {J_style.numpy()}")

    # Return the total style loss
    return J_style

# %%
# Function to compute content loss between the style and generated images
def content_cost(content, generated):
    # Initialize the total content loss (J_content) to 0
    J_content = 0
    #print("Initialized total content loss: J_content = 0")

    # Get the content activations for the content and generated images from the content model
    a_C = content_model(content)
    #print(f"Content activations (Layer {content_layer}): {a_C.shape}")

    a_G = content_model(generated)
    #print(f"Generated activations (Layer {content_layer}): {a_G.shape}")

    # Compute the content loss (mean squared error between the activations)
    content_cost = tf.reduce_mean(tf.square(a_C - a_G))
    #print(f"Content loss (MSE between activations): {content_cost.numpy()}")

    # Add the content loss to the total content loss
    J_content += content_cost
    #print(f"Updated total content loss: {J_content.numpy()}")

    # Return the total content loss
    return J_content

# %%
# List to store generated images at each iteration for visualization
generated_images = []

# Training function for optimizing the generated image using content and style losses
def training_loop(content_path, style_path, iterations=100, a=10, b=1000):
    # Load and preprocess content and style images from their respective paths
    content = load_and_process_image(content_path)
    style = load_and_process_image(style_path)

    # Initialize the generated image as a trainable variable, starting from the content image
    generated = tf.Variable(content, dtype=tf.float32)

    # Adam optimizer with a learning rate of 7.9
    opt = tf.keras.optimizers.Adam(learning_rate=7.9)

    # Initialize best cost and best image trackers
    best_cost = math.inf
    best_image = None

    # Start the optimization loop for a given number of iterations
    for i in range(iterations):
        # Record start time for CPU and wall time
        start_time_cpu = time.process_time()
        start_time_wall = time.time()

        # Use GradientTape to track operations on the generated image
        with tf.GradientTape() as tape:
            # Compute content loss
            J_content = content_cost(content, generated)  # Note: Pass the content, not style
            # Compute style loss
            J_style = style_cost(style, generated)
            # Compute total loss as a weighted sum of content and style losses
            J_total = a * J_content + b * J_style

        # Compute the gradients of the total loss with respect to the generated image
        grads = tape.gradient(J_total, generated)
        # Apply gradients to the generated image to minimize the total loss
        opt.apply_gradients([(grads, generated)])

        # Record end time for CPU and wall time
        end_time_cpu = time.process_time()  # Record end time for CPU
        end_time_wall = time.time()  # Record end time for wall time

        # Calculate the CPU time (time spent on computations) and wall time (real elapsed time)
        cpu_time = end_time_cpu - start_time_cpu
        wall_time = end_time_wall - start_time_wall

        # If the total loss improves (becomes smaller), store the best image and loss
        if J_total < best_cost:
            best_cost = J_total
            best_image = generated.numpy()

        # Print CPU times (user, system, and total time)
        print("CPU times: user {} µs, sys: {} ns, total: {} µs".format(
            int(cpu_time * 1e6),  # Convert seconds to microseconds for user time
            int((end_time_cpu - start_time_cpu) * 1e9),  # Convert seconds to nanoseconds for system time
            int((end_time_cpu - start_time_cpu + 1e-6) * 1e6)  # Convert seconds to microseconds for total time
        ))

        # Print wall time (real time taken for each iteration)
        print("Wall time: {:.2f} µs".format(wall_time * 1e6))  # Convert seconds to microseconds

        # Print the current iteration and total loss for each iteration
        print("Iteration: {}".format(i))
        print('Total Loss: {:e}'.format(J_total))  # Print the total loss in scientific notation
        print('--------------------------------------------------------')
        # Append the current generated image to the list for later visualization
        generated_images.append(generated.numpy())

    # Return the best generated image found during optimization
    return best_image

# %%
# Train the model and get best image
final_img = training_loop(content_img_path, style_img_path)
# Out:
# Image shape after adding batch dimension: (1, 225, 225, 3)
# Image shape after adding batch dimension: (1, 194, 260, 3)
# Style loss for layer block1_conv1: 4794985.5
# Updated total style loss: 1598328.5
# Style loss for layer block3_conv1: 1845004800.0
# Updated total style loss: 616599936.0
# Style loss for layer block5_conv1: 67782448.0
# Updated total style loss: 639194112.0
# CPU times: user 1997734 µs, sys: 1997734480 ns, total: 1997735 µs
# Wall time: 2138632.54 µs
# Iteration: 0
# Total Loss: 6.391941e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4841046.5
# Updated total style loss: 1613682.25
# Style loss for layer block3_conv1: 1109302272.0
# Updated total style loss: 371381120.0
# Style loss for layer block5_conv1: 53532364.0
# Updated total style loss: 389225248.0
# CPU times: user 270648 µs, sys: 270648370 ns, total: 270649 µs
# Wall time: 284799.34 µs
# Iteration: 1
# Total Loss: 3.892253e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4867651.5
# Updated total style loss: 1622550.5
# Style loss for layer block3_conv1: 764120064.0
# Updated total style loss: 256329232.0
# Style loss for layer block5_conv1: 40123628.0
# Updated total style loss: 269703776.0
# CPU times: user 302330 µs, sys: 302330006 ns, total: 302331 µs
# Wall time: 337035.89 µs
# Iteration: 2
# Total Loss: 2.697038e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4881070.0
# Updated total style loss: 1627023.375
# Style loss for layer block3_conv1: 614942208.0
# Updated total style loss: 206607760.0
# Style loss for layer block5_conv1: 32687876.0
# Updated total style loss: 217503712.0
# CPU times: user 294332 µs, sys: 294332558 ns, total: 294333 µs
# Wall time: 322039.37 µs
# Iteration: 3
# Total Loss: 2.175037e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4885318.5
# Updated total style loss: 1628439.5
# Style loss for layer block3_conv1: 532343488.0
# Updated total style loss: 179076272.0
# Style loss for layer block5_conv1: 28538122.0
# Updated total style loss: 188588976.0
# CPU times: user 305322 µs, sys: 305322873 ns, total: 305323 µs
# Wall time: 320598.60 µs
# Iteration: 4
# Total Loss: 1.885890e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4875621.5
# Updated total style loss: 1625207.25
# Style loss for layer block3_conv1: 468310400.0
# Updated total style loss: 157728672.0
# Style loss for layer block5_conv1: 27043428.0
# Updated total style loss: 166743152.0
# CPU times: user 212624 µs, sys: 212624274 ns, total: 212625 µs
# Wall time: 212729.22 µs
# Iteration: 5
# Total Loss: 1.667432e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4850211.0
# Updated total style loss: 1616737.0
# Style loss for layer block3_conv1: 429974112.0
# Updated total style loss: 144941440.0
# Style loss for layer block5_conv1: 26981132.0
# Updated total style loss: 153935152.0
# CPU times: user 195946 µs, sys: 195946369 ns, total: 195947 µs
# Wall time: 195731.40 µs
# Iteration: 6
# Total Loss: 1.539352e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4808640.0
# Updated total style loss: 1602880.0
# Style loss for layer block3_conv1: 399142656.0
# Updated total style loss: 134650432.0
# Style loss for layer block5_conv1: 26187376.0
# Updated total style loss: 143379552.0
# CPU times: user 206510 µs, sys: 206510348 ns, total: 206511 µs
# Wall time: 207619.43 µs
# Iteration: 7
# Total Loss: 1.433796e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4751841.5
# Updated total style loss: 1583947.25
# Style loss for layer block3_conv1: 369535296.0
# Updated total style loss: 124762376.0
# Style loss for layer block5_conv1: 24648400.0
# Updated total style loss: 132978512.0
# CPU times: user 196358 µs, sys: 196358728 ns, total: 196359 µs
# Wall time: 195524.93 µs
# Iteration: 8
# Total Loss: 1.329786e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4680852.0
# Updated total style loss: 1560284.0
# Style loss for layer block3_conv1: 339918752.0
# Updated total style loss: 114866544.0
# Style loss for layer block5_conv1: 22984848.0
# Updated total style loss: 122528160.0
# CPU times: user 200511 µs, sys: 200511742 ns, total: 200512 µs
# Wall time: 202808.38 µs
# Iteration: 9
# Total Loss: 1.225282e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4597862.5
# Updated total style loss: 1532620.875
# Style loss for layer block3_conv1: 312785792.0
# Updated total style loss: 105794560.0
# Style loss for layer block5_conv1: 21420560.0
# Updated total style loss: 112934744.0
# CPU times: user 197420 µs, sys: 197420992 ns, total: 197421 µs
# Wall time: 196444.03 µs
# Iteration: 10
# Total Loss: 1.129348e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4505545.5
# Updated total style loss: 1501848.5
# Style loss for layer block3_conv1: 288928224.0
# Updated total style loss: 97811256.0
# Style loss for layer block5_conv1: 19933532.0
# Updated total style loss: 104455768.0
# CPU times: user 212444 µs, sys: 212444195 ns, total: 212445 µs
# Wall time: 211739.54 µs
# Iteration: 11
# Total Loss: 1.044558e+11
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4406506.0
# Updated total style loss: 1468835.375
# Style loss for layer block3_conv1: 267450624.0
# Updated total style loss: 90619040.0
# Style loss for layer block5_conv1: 18708430.0
# Updated total style loss: 96855184.0
# CPU times: user 208854 µs, sys: 208854927 ns, total: 208855 µs
# Wall time: 209056.85 µs
# Iteration: 12
# Total Loss: 9.685524e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4303205.5
# Updated total style loss: 1434401.875
# Style loss for layer block3_conv1: 246977264.0
# Updated total style loss: 83760160.0
# Style loss for layer block5_conv1: 17615018.0
# Updated total style loss: 89631832.0
# CPU times: user 203999 µs, sys: 203999741 ns, total: 204000 µs
# Wall time: 203861.95 µs
# Iteration: 13
# Total Loss: 8.963188e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4197544.0
# Updated total style loss: 1399181.375
# Style loss for layer block3_conv1: 227027744.0
# Updated total style loss: 77075104.0
# Style loss for layer block5_conv1: 16655593.0
# Updated total style loss: 82626968.0
# CPU times: user 206448 µs, sys: 206448380 ns, total: 206449 µs
# Wall time: 205718.76 µs
# Iteration: 14
# Total Loss: 8.262702e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 4090781.75
# Updated total style loss: 1363594.0
# Style loss for layer block3_conv1: 208270544.0
# Updated total style loss: 70787112.0
# Style loss for layer block5_conv1: 15810112.0
# Updated total style loss: 76057152.0
# CPU times: user 209206 µs, sys: 209206921 ns, total: 209207 µs
# Wall time: 207649.47 µs
# Iteration: 15
# Total Loss: 7.605720e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3983853.0
# Updated total style loss: 1327951.0
# Style loss for layer block3_conv1: 191032000.0
# Updated total style loss: 65005288.0
# Style loss for layer block5_conv1: 15083700.0
# Updated total style loss: 70033184.0
# CPU times: user 214223 µs, sys: 214223428 ns, total: 214224 µs
# Wall time: 213695.53 µs
# Iteration: 16
# Total Loss: 7.003324e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3877359.25
# Updated total style loss: 1292453.125
# Style loss for layer block3_conv1: 175541264.0
# Updated total style loss: 59806208.0
# Style loss for layer block5_conv1: 14500006.0
# Updated total style loss: 64639544.0
# CPU times: user 202353 µs, sys: 202353954 ns, total: 202354 µs
# Wall time: 201447.96 µs
# Iteration: 17
# Total Loss: 6.463960e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3771940.75
# Updated total style loss: 1257313.625
# Style loss for layer block3_conv1: 161415264.0
# Updated total style loss: 55062400.0
# Style loss for layer block5_conv1: 13998979.0
# Updated total style loss: 59728728.0
# CPU times: user 205287 µs, sys: 205287905 ns, total: 205288 µs
# Wall time: 206053.97 µs
# Iteration: 18
# Total Loss: 5.972878e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3668099.0
# Updated total style loss: 1222699.75
# Style loss for layer block3_conv1: 148607392.0
# Updated total style loss: 50758500.0
# Style loss for layer block5_conv1: 13535120.0
# Updated total style loss: 55270208.0
# CPU times: user 205493 µs, sys: 205493028 ns, total: 205494 µs
# Wall time: 204716.21 µs
# Iteration: 19
# Total Loss: 5.527026e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3566514.75
# Updated total style loss: 1188838.25
# Style loss for layer block3_conv1: 137161392.0
# Updated total style loss: 46909304.0
# Style loss for layer block5_conv1: 13106085.0
# Updated total style loss: 51278000.0
# CPU times: user 216013 µs, sys: 216013234 ns, total: 216014 µs
# Wall time: 215359.93 µs
# Iteration: 20
# Total Loss: 5.127805e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3467705.75
# Updated total style loss: 1155902.0
# Style loss for layer block3_conv1: 126984496.0
# Updated total style loss: 43484072.0
# Style loss for layer block5_conv1: 12723727.0
# Updated total style loss: 47725316.0
# CPU times: user 207697 µs, sys: 207697317 ns, total: 207698 µs
# Wall time: 206905.60 µs
# Iteration: 21
# Total Loss: 4.772537e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3372170.0
# Updated total style loss: 1124056.75
# Style loss for layer block3_conv1: 117597704.0
# Updated total style loss: 40323292.0
# Style loss for layer block5_conv1: 12342065.0
# Updated total style loss: 44437312.0
# CPU times: user 203036 µs, sys: 203036913 ns, total: 203037 µs
# Wall time: 203089.71 µs
# Iteration: 22
# Total Loss: 4.443737e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3280194.0
# Updated total style loss: 1093398.0
# Style loss for layer block3_conv1: 109048592.0
# Updated total style loss: 37442928.0
# Style loss for layer block5_conv1: 11970562.0
# Updated total style loss: 41433116.0
# CPU times: user 212604 µs, sys: 212604630 ns, total: 212605 µs
# Wall time: 213277.58 µs
# Iteration: 23
# Total Loss: 4.143317e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3191834.5
# Updated total style loss: 1063944.875
# Style loss for layer block3_conv1: 101419336.0
# Updated total style loss: 34870392.0
# Style loss for layer block5_conv1: 11587366.0
# Updated total style loss: 38732848.0
# CPU times: user 206936 µs, sys: 206936044 ns, total: 206937 µs
# Wall time: 205755.95 µs
# Iteration: 24
# Total Loss: 3.873291e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3107151.0
# Updated total style loss: 1035717.0
# Style loss for layer block3_conv1: 94582848.0
# Updated total style loss: 32563332.0
# Style loss for layer block5_conv1: 11199428.0
# Updated total style loss: 36296476.0
# CPU times: user 217881 µs, sys: 217881684 ns, total: 217882 µs
# Wall time: 217603.92 µs
# Iteration: 25
# Total Loss: 3.629653e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 3026143.25
# Updated total style loss: 1008714.4375
# Style loss for layer block3_conv1: 88369248.0
# Updated total style loss: 30465130.0
# Style loss for layer block5_conv1: 10830280.0
# Updated total style loss: 34075224.0
# CPU times: user 199018 µs, sys: 199018041 ns, total: 199019 µs
# Wall time: 197501.18 µs
# Iteration: 26
# Total Loss: 3.407528e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2948869.5
# Updated total style loss: 982956.5
# Style loss for layer block3_conv1: 82800112.0
# Updated total style loss: 28582994.0
# Style loss for layer block5_conv1: 10521026.0
# Updated total style loss: 32090002.0
# CPU times: user 204675 µs, sys: 204675568 ns, total: 204676 µs
# Wall time: 203663.59 µs
# Iteration: 27
# Total Loss: 3.209006e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2875293.5
# Updated total style loss: 958431.1875
# Style loss for layer block3_conv1: 77666968.0
# Updated total style loss: 26847422.0
# Style loss for layer block5_conv1: 10263956.0
# Updated total style loss: 30268740.0
# CPU times: user 203229 µs, sys: 203229923 ns, total: 203230 µs
# Wall time: 201852.80 µs
# Iteration: 28
# Total Loss: 3.026880e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2805381.75
# Updated total style loss: 935127.25
# Style loss for layer block3_conv1: 72878696.0
# Updated total style loss: 25228028.0
# Style loss for layer block5_conv1: 10027228.0
# Updated total style loss: 28570438.0
# CPU times: user 213011 µs, sys: 213011255 ns, total: 213012 µs
# Wall time: 212505.34 µs
# Iteration: 29
# Total Loss: 2.857049e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2739015.5
# Updated total style loss: 913005.1875
# Style loss for layer block3_conv1: 68415808.0
# Updated total style loss: 23718276.0
# Style loss for layer block5_conv1: 9804712.0
# Updated total style loss: 26986514.0
# CPU times: user 197965 µs, sys: 197965734 ns, total: 197966 µs
# Wall time: 197290.42 µs
# Iteration: 30
# Total Loss: 2.698657e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2676151.75
# Updated total style loss: 892050.625
# Style loss for layer block3_conv1: 64352952.0
# Updated total style loss: 22343034.0
# Style loss for layer block5_conv1: 9595642.0
# Updated total style loss: 25541582.0
# CPU times: user 204437 µs, sys: 204437395 ns, total: 204438 µs
# Wall time: 204613.69 µs
# Iteration: 31
# Total Loss: 2.554164e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2616794.5
# Updated total style loss: 872264.875
# Style loss for layer block3_conv1: 60674420.0
# Updated total style loss: 21097072.0
# Style loss for layer block5_conv1: 9403119.0
# Updated total style loss: 24231444.0
# CPU times: user 197197 µs, sys: 197197552 ns, total: 197198 µs
# Wall time: 196569.20 µs
# Iteration: 32
# Total Loss: 2.423150e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2560751.25
# Updated total style loss: 853583.75
# Style loss for layer block3_conv1: 57321424.0
# Updated total style loss: 19960726.0
# Style loss for layer block5_conv1: 9212672.0
# Updated total style loss: 23031616.0
# CPU times: user 197544 µs, sys: 197544609 ns, total: 197545 µs
# Wall time: 197899.10 µs
# Iteration: 33
# Total Loss: 2.303167e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2507875.0
# Updated total style loss: 835958.375
# Style loss for layer block3_conv1: 54253528.0
# Updated total style loss: 18920468.0
# Style loss for layer block5_conv1: 9019565.0
# Updated total style loss: 21926990.0
# CPU times: user 212484 µs, sys: 212484323 ns, total: 212485 µs
# Wall time: 211488.49 µs
# Iteration: 34
# Total Loss: 2.192705e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2457963.75
# Updated total style loss: 819321.25
# Style loss for layer block3_conv1: 51421920.0
# Updated total style loss: 17959962.0
# Style loss for layer block5_conv1: 8843950.0
# Updated total style loss: 20907946.0
# CPU times: user 200985 µs, sys: 200985024 ns, total: 200986 µs
# Wall time: 204514.50 µs
# Iteration: 35
# Total Loss: 2.090801e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2410824.25
# Updated total style loss: 803608.125
# Style loss for layer block3_conv1: 48824752.0
# Updated total style loss: 17078526.0
# Style loss for layer block5_conv1: 8680149.0
# Updated total style loss: 19971908.0
# CPU times: user 202335 µs, sys: 202335868 ns, total: 202336 µs
# Wall time: 201415.78 µs
# Iteration: 36
# Total Loss: 1.997197e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2366248.0
# Updated total style loss: 788749.375
# Style loss for layer block3_conv1: 46412600.0
# Updated total style loss: 16259616.0
# Style loss for layer block5_conv1: 8525399.0
# Updated total style loss: 19101416.0
# CPU times: user 200373 µs, sys: 200373624 ns, total: 200374 µs
# Wall time: 199509.38 µs
# Iteration: 37
# Total Loss: 1.910147e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2324050.0
# Updated total style loss: 774683.375
# Style loss for layer block3_conv1: 44169148.0
# Updated total style loss: 15497733.0
# Style loss for layer block5_conv1: 8370830.0
# Updated total style loss: 18288010.0
# CPU times: user 224146 µs, sys: 224146372 ns, total: 224147 µs
# Wall time: 225703.48 µs
# Iteration: 38
# Total Loss: 1.828807e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2284101.75
# Updated total style loss: 761367.25
# Style loss for layer block3_conv1: 42104048.0
# Updated total style loss: 14796050.0
# Style loss for layer block5_conv1: 8221479.0
# Updated total style loss: 17536544.0
# CPU times: user 203745 µs, sys: 203745886 ns, total: 203746 µs
# Wall time: 203057.05 µs
# Iteration: 39
# Total Loss: 1.753660e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2246275.75
# Updated total style loss: 748758.625
# Style loss for layer block3_conv1: 40223528.0
# Updated total style loss: 14156602.0
# Style loss for layer block5_conv1: 8074414.0
# Updated total style loss: 16848074.0
# CPU times: user 200832 µs, sys: 200832564 ns, total: 200833 µs
# Wall time: 199677.47 µs
# Iteration: 40
# Total Loss: 1.684813e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2210490.0
# Updated total style loss: 736830.0
# Style loss for layer block3_conv1: 38509940.0
# Updated total style loss: 13573477.0
# Style loss for layer block5_conv1: 7929654.0
# Updated total style loss: 16216695.0
# CPU times: user 203312 µs, sys: 203312455 ns, total: 203313 µs
# Wall time: 202397.35 µs
# Iteration: 41
# Total Loss: 1.621675e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2176619.75
# Updated total style loss: 725539.9375
# Style loss for layer block3_conv1: 36930544.0
# Updated total style loss: 13035722.0
# Style loss for layer block5_conv1: 7794527.0
# Updated total style loss: 15633898.0
# CPU times: user 198283 µs, sys: 198283809 ns, total: 198284 µs
# Wall time: 197609.19 µs
# Iteration: 42
# Total Loss: 1.563396e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2144525.25
# Updated total style loss: 714841.75
# Style loss for layer block3_conv1: 35457128.0
# Updated total style loss: 12533885.0
# Style loss for layer block5_conv1: 7662818.0
# Updated total style loss: 15088158.0
# CPU times: user 204195 µs, sys: 204195257 ns, total: 204196 µs
# Wall time: 204071.76 µs
# Iteration: 43
# Total Loss: 1.508822e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2114049.0
# Updated total style loss: 704683.0
# Style loss for layer block3_conv1: 34071440.0
# Updated total style loss: 12061830.0
# Style loss for layer block5_conv1: 7536819.5
# Updated total style loss: 14574103.0
# CPU times: user 197101 µs, sys: 197101525 ns, total: 197102 µs
# Wall time: 196041.82 µs
# Iteration: 44
# Total Loss: 1.457416e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2085047.75
# Updated total style loss: 695015.9375
# Style loss for layer block3_conv1: 32768428.0
# Updated total style loss: 11617826.0
# Style loss for layer block5_conv1: 7416439.5
# Updated total style loss: 14089972.0
# CPU times: user 192712 µs, sys: 192712244 ns, total: 192713 µs
# Wall time: 192524.19 µs
# Iteration: 45
# Total Loss: 1.409003e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2057421.625
# Updated total style loss: 685807.25
# Style loss for layer block3_conv1: 31551494.0
# Updated total style loss: 11202972.0
# Style loss for layer block5_conv1: 7298183.0
# Updated total style loss: 13635700.0
# CPU times: user 197095 µs, sys: 197095218 ns, total: 197096 µs
# Wall time: 196221.35 µs
# Iteration: 46
# Total Loss: 1.363576e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2031094.875
# Updated total style loss: 677031.625
# Style loss for layer block3_conv1: 30432468.0
# Updated total style loss: 10821188.0
# Style loss for layer block5_conv1: 7174880.0
# Updated total style loss: 13212815.0
# CPU times: user 209533 µs, sys: 209533703 ns, total: 209534 µs
# Wall time: 208926.68 µs
# Iteration: 47
# Total Loss: 1.321288e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 2005979.625
# Updated total style loss: 668659.875
# Style loss for layer block3_conv1: 29373800.0
# Updated total style loss: 10459927.0
# Style loss for layer block5_conv1: 7050275.0
# Updated total style loss: 12810019.0
# CPU times: user 231743 µs, sys: 231743244 ns, total: 231744 µs
# Wall time: 233197.93 µs
# Iteration: 48
# Total Loss: 1.281008e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1982006.625
# Updated total style loss: 660668.875
# Style loss for layer block3_conv1: 28377502.0
# Updated total style loss: 10119837.0
# Style loss for layer block5_conv1: 6933581.0
# Updated total style loss: 12431031.0
# CPU times: user 276967 µs, sys: 276967286 ns, total: 276968 µs
# Wall time: 287213.80 µs
# Iteration: 49
# Total Loss: 1.243109e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1959092.625
# Updated total style loss: 653030.875
# Style loss for layer block3_conv1: 27438126.0
# Updated total style loss: 9799073.0
# Style loss for layer block5_conv1: 6819595.0
# Updated total style loss: 12072272.0
# CPU times: user 259408 µs, sys: 259408237 ns, total: 259409 µs
# Wall time: 264427.66 µs
# Iteration: 50
# Total Loss: 1.207233e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1937148.875
# Updated total style loss: 645716.3125
# Style loss for layer block3_conv1: 26556764.0
# Updated total style loss: 9497971.0
# Style loss for layer block5_conv1: 6713552.0
# Updated total style loss: 11735822.0
# CPU times: user 253769 µs, sys: 253769523 ns, total: 253770 µs
# Wall time: 275547.98 µs
# Iteration: 51
# Total Loss: 1.173588e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1916129.25
# Updated total style loss: 638709.75
# Style loss for layer block3_conv1: 25727870.0
# Updated total style loss: 9214667.0
# Style loss for layer block5_conv1: 6609549.5
# Updated total style loss: 11417850.0
# CPU times: user 253276 µs, sys: 253276754 ns, total: 253277 µs
# Wall time: 262043.00 µs
# Iteration: 52
# Total Loss: 1.141791e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1895978.625
# Updated total style loss: 631992.875
# Style loss for layer block3_conv1: 24954684.0
# Updated total style loss: 8950221.0
# Style loss for layer block5_conv1: 6508911.0
# Updated total style loss: 11119858.0
# CPU times: user 279215 µs, sys: 279215811 ns, total: 279216 µs
# Wall time: 288002.73 µs
# Iteration: 53
# Total Loss: 1.111992e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1876644.625
# Updated total style loss: 625548.25
# Style loss for layer block3_conv1: 24228306.0
# Updated total style loss: 8701650.0
# Style loss for layer block5_conv1: 6413892.0
# Updated total style loss: 10839614.0
# CPU times: user 288146 µs, sys: 288146369 ns, total: 288147 µs
# Wall time: 294609.07 µs
# Iteration: 54
# Total Loss: 1.083968e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1858069.375
# Updated total style loss: 619356.5
# Style loss for layer block3_conv1: 23537026.0
# Updated total style loss: 8465032.0
# Style loss for layer block5_conv1: 6326818.0
# Updated total style loss: 10573972.0
# CPU times: user 295943 µs, sys: 295943980 ns, total: 295944 µs
# Wall time: 313609.12 µs
# Iteration: 55
# Total Loss: 1.057403e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1840215.0
# Updated total style loss: 613405.0
# Style loss for layer block3_conv1: 22878206.0
# Updated total style loss: 8239474.0
# Style loss for layer block5_conv1: 6244440.0
# Updated total style loss: 10320954.0
# CPU times: user 225079 µs, sys: 225079926 ns, total: 225080 µs
# Wall time: 232329.37 µs
# Iteration: 56
# Total Loss: 1.032102e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1823052.25
# Updated total style loss: 607684.125
# Style loss for layer block3_conv1: 22255796.0
# Updated total style loss: 8026283.0
# Style loss for layer block5_conv1: 6167093.0
# Updated total style loss: 10081981.0
# CPU times: user 211672 µs, sys: 211672134 ns, total: 211673 µs
# Wall time: 211904.05 µs
# Iteration: 57
# Total Loss: 1.008204e+10
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1806554.625
# Updated total style loss: 602184.875
# Style loss for layer block3_conv1: 21666664.0
# Updated total style loss: 7824406.5
# Style loss for layer block5_conv1: 6094786.0
# Updated total style loss: 9856002.0
# CPU times: user 200343 µs, sys: 200343917 ns, total: 200344 µs
# Wall time: 200632.33 µs
# Iteration: 58
# Total Loss: 9.856065e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1790696.25
# Updated total style loss: 596898.75
# Style loss for layer block3_conv1: 21106902.0
# Updated total style loss: 7632533.0
# Style loss for layer block5_conv1: 6026111.0
# Updated total style loss: 9641237.0
# CPU times: user 204363 µs, sys: 204363912 ns, total: 204364 µs
# Wall time: 204991.34 µs
# Iteration: 59
# Total Loss: 9.641301e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1775430.875
# Updated total style loss: 591810.3125
# Style loss for layer block3_conv1: 20570966.0
# Updated total style loss: 7448799.5
# Style loss for layer block5_conv1: 5961670.5
# Updated total style loss: 9436023.0
# CPU times: user 200447 µs, sys: 200447934 ns, total: 200448 µs
# Wall time: 199141.03 µs
# Iteration: 60
# Total Loss: 9.436086e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1760701.875
# Updated total style loss: 586900.625
# Style loss for layer block3_conv1: 20061824.0
# Updated total style loss: 7274175.5
# Style loss for layer block5_conv1: 5897112.0
# Updated total style loss: 9239880.0
# CPU times: user 194830 µs, sys: 194830948 ns, total: 194831 µs
# Wall time: 193913.70 µs
# Iteration: 61
# Total Loss: 9.239943e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1746453.25
# Updated total style loss: 582151.125
# Style loss for layer block3_conv1: 19580474.0
# Updated total style loss: 7108976.0
# Style loss for layer block5_conv1: 5831774.5
# Updated total style loss: 9052901.0
# CPU times: user 196519 µs, sys: 196519230 ns, total: 196520 µs
# Wall time: 196114.78 µs
# Iteration: 62
# Total Loss: 9.052965e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1732628.0
# Updated total style loss: 577542.6875
# Style loss for layer block3_conv1: 19127412.0
# Updated total style loss: 6953346.5
# Style loss for layer block5_conv1: 5764246.0
# Updated total style loss: 8874762.0
# CPU times: user 209318 µs, sys: 209318291 ns, total: 209319 µs
# Wall time: 210147.62 µs
# Iteration: 63
# Total Loss: 8.874826e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1719192.25
# Updated total style loss: 573064.125
# Style loss for layer block3_conv1: 18698782.0
# Updated total style loss: 6805991.5
# Style loss for layer block5_conv1: 5697669.0
# Updated total style loss: 8705214.0
# CPU times: user 208325 µs, sys: 208325363 ns, total: 208326 µs
# Wall time: 207043.17 µs
# Iteration: 64
# Total Loss: 8.705278e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1706125.875
# Updated total style loss: 568708.625
# Style loss for layer block3_conv1: 18287268.0
# Updated total style loss: 6664464.5
# Style loss for layer block5_conv1: 5632742.0
# Updated total style loss: 8542045.0
# CPU times: user 197707 µs, sys: 197707648 ns, total: 197708 µs
# Wall time: 196820.02 µs
# Iteration: 65
# Total Loss: 8.542109e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1693409.25
# Updated total style loss: 564469.75
# Style loss for layer block3_conv1: 17896988.0
# Updated total style loss: 6530133.0
# Style loss for layer block5_conv1: 5568837.0
# Updated total style loss: 8386412.0
# CPU times: user 194473 µs, sys: 194473060 ns, total: 194474 µs
# Wall time: 194241.29 µs
# Iteration: 66
# Total Loss: 8.386476e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1681027.0
# Updated total style loss: 560342.375
# Style loss for layer block3_conv1: 17524480.0
# Updated total style loss: 6401836.0
# Style loss for layer block5_conv1: 5510179.0
# Updated total style loss: 8238562.5
# CPU times: user 206106 µs, sys: 206106997 ns, total: 206107 µs
# Wall time: 205882.31 µs
# Iteration: 67
# Total Loss: 8.238626e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1668972.875
# Updated total style loss: 556324.3125
# Style loss for layer block3_conv1: 17167596.0
# Updated total style loss: 6278856.5
# Style loss for layer block5_conv1: 5455440.5
# Updated total style loss: 8097337.0
# CPU times: user 212694 µs, sys: 212694557 ns, total: 212695 µs
# Wall time: 213052.75 µs
# Iteration: 68
# Total Loss: 8.097401e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1657232.25
# Updated total style loss: 552410.75
# Style loss for layer block3_conv1: 16821072.0
# Updated total style loss: 6159435.0
# Style loss for layer block5_conv1: 5403890.0
# Updated total style loss: 7960732.0
# CPU times: user 208530 µs, sys: 208530185 ns, total: 208531 µs
# Wall time: 208576.20 µs
# Iteration: 69
# Total Loss: 7.960797e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1645777.375
# Updated total style loss: 548592.5
# Style loss for layer block3_conv1: 16486673.0
# Updated total style loss: 6044150.5
# Style loss for layer block5_conv1: 5354939.5
# Updated total style loss: 7829130.5
# CPU times: user 202823 µs, sys: 202823000 ns, total: 202824 µs
# Wall time: 203392.98 µs
# Iteration: 70
# Total Loss: 7.829195e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1634575.25
# Updated total style loss: 544858.4375
# Style loss for layer block3_conv1: 16170342.0
# Updated total style loss: 5934972.5
# Style loss for layer block5_conv1: 5307027.5
# Updated total style loss: 7703982.0
# CPU times: user 209013 µs, sys: 209013935 ns, total: 209014 µs
# Wall time: 207503.32 µs
# Iteration: 71
# Total Loss: 7.704047e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1623607.625
# Updated total style loss: 541202.5625
# Style loss for layer block3_conv1: 15868620.0
# Updated total style loss: 5830742.5
# Style loss for layer block5_conv1: 5260372.0
# Updated total style loss: 7584200.0
# CPU times: user 214361 µs, sys: 214361498 ns, total: 214362 µs
# Wall time: 214125.63 µs
# Iteration: 72
# Total Loss: 7.584265e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1612868.25
# Updated total style loss: 537622.75
# Style loss for layer block3_conv1: 15580550.0
# Updated total style loss: 5731140.0
# Style loss for layer block5_conv1: 5217528.5
# Updated total style loss: 7470316.0
# CPU times: user 205442 µs, sys: 205442987 ns, total: 205443 µs
# Wall time: 204496.38 µs
# Iteration: 73
# Total Loss: 7.470381e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1602355.375
# Updated total style loss: 534118.5
# Style loss for layer block3_conv1: 15303562.0
# Updated total style loss: 5635306.0
# Style loss for layer block5_conv1: 5175664.5
# Updated total style loss: 7360527.5
# CPU times: user 207767 µs, sys: 207767582 ns, total: 207768 µs
# Wall time: 208175.90 µs
# Iteration: 74
# Total Loss: 7.360592e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1592067.125
# Updated total style loss: 530689.0625
# Style loss for layer block3_conv1: 15036308.0
# Updated total style loss: 5542792.0
# Style loss for layer block5_conv1: 5135817.0
# Updated total style loss: 7254731.0
# CPU times: user 207321 µs, sys: 207321127 ns, total: 207322 µs
# Wall time: 207000.49 µs
# Iteration: 75
# Total Loss: 7.254796e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1581990.5
# Updated total style loss: 527330.1875
# Style loss for layer block3_conv1: 14778262.0
# Updated total style loss: 5453417.5
# Style loss for layer block5_conv1: 5097820.5
# Updated total style loss: 7152691.0
# CPU times: user 205442 µs, sys: 205442371 ns, total: 205443 µs
# Wall time: 204684.97 µs
# Iteration: 76
# Total Loss: 7.152756e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1572116.75
# Updated total style loss: 524038.9375
# Style loss for layer block3_conv1: 14529864.0
# Updated total style loss: 5367327.0
# Style loss for layer block5_conv1: 5061783.0
# Updated total style loss: 7054588.0
# CPU times: user 214811 µs, sys: 214811198 ns, total: 214812 µs
# Wall time: 215525.15 µs
# Iteration: 77
# Total Loss: 7.054653e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1562443.25
# Updated total style loss: 520814.4375
# Style loss for layer block3_conv1: 14291392.0
# Updated total style loss: 5284612.0
# Style loss for layer block5_conv1: 5026643.5
# Updated total style loss: 6960160.0
# CPU times: user 196153 µs, sys: 196153954 ns, total: 196154 µs
# Wall time: 195119.14 µs
# Iteration: 78
# Total Loss: 6.960225e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1552963.25
# Updated total style loss: 517654.4375
# Style loss for layer block3_conv1: 14063468.0
# Updated total style loss: 5205477.5
# Style loss for layer block5_conv1: 4992486.0
# Updated total style loss: 6869639.5
# CPU times: user 203758 µs, sys: 203758431 ns, total: 203759 µs
# Wall time: 204984.66 µs
# Iteration: 79
# Total Loss: 6.869705e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1543666.625
# Updated total style loss: 514555.5625
# Style loss for layer block3_conv1: 13843680.0
# Updated total style loss: 5129115.5
# Style loss for layer block5_conv1: 4959071.5
# Updated total style loss: 6782139.5
# CPU times: user 195448 µs, sys: 195448421 ns, total: 195449 µs
# Wall time: 195161.34 µs
# Iteration: 80
# Total Loss: 6.782204e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1534527.0
# Updated total style loss: 511509.0
# Style loss for layer block3_conv1: 13629150.0
# Updated total style loss: 5054559.0
# Style loss for layer block5_conv1: 4927105.0
# Updated total style loss: 6696927.5
# CPU times: user 213108 µs, sys: 213108078 ns, total: 213109 µs
# Wall time: 212458.37 µs
# Iteration: 81
# Total Loss: 6.696993e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1525533.75
# Updated total style loss: 508511.25
# Style loss for layer block3_conv1: 13419767.0
# Updated total style loss: 4981767.0
# Style loss for layer block5_conv1: 4897207.0
# Updated total style loss: 6614169.5
# CPU times: user 215576 µs, sys: 215576886 ns, total: 215577 µs
# Wall time: 216460.47 µs
# Iteration: 82
# Total Loss: 6.614235e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1516689.75
# Updated total style loss: 505563.25
# Style loss for layer block3_conv1: 13218390.0
# Updated total style loss: 4911693.0
# Style loss for layer block5_conv1: 4866573.0
# Updated total style loss: 6533884.0
# CPU times: user 211013 µs, sys: 211013632 ns, total: 211014 µs
# Wall time: 211682.56 µs
# Iteration: 83
# Total Loss: 6.533949e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1507992.0
# Updated total style loss: 502664.0
# Style loss for layer block3_conv1: 13025199.0
# Updated total style loss: 4844397.0
# Style loss for layer block5_conv1: 4834800.5
# Updated total style loss: 6455997.0
# CPU times: user 205835 µs, sys: 205835815 ns, total: 205836 µs
# Wall time: 209503.89 µs
# Iteration: 84
# Total Loss: 6.456062e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1499438.125
# Updated total style loss: 499812.71875
# Style loss for layer block3_conv1: 12840124.0
# Updated total style loss: 4779854.0
# Style loss for layer block5_conv1: 4803700.0
# Updated total style loss: 6381087.5
# CPU times: user 196842 µs, sys: 196842761 ns, total: 196843 µs
# Wall time: 196202.04 µs
# Iteration: 85
# Total Loss: 6.381153e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1491023.875
# Updated total style loss: 497007.96875
# Style loss for layer block3_conv1: 12659492.0
# Updated total style loss: 4716839.0
# Style loss for layer block5_conv1: 4772708.0
# Updated total style loss: 6307742.0
# CPU times: user 214646 µs, sys: 214646404 ns, total: 214647 µs
# Wall time: 214050.05 µs
# Iteration: 86
# Total Loss: 6.307808e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1482735.5
# Updated total style loss: 494245.1875
# Style loss for layer block3_conv1: 12485166.0
# Updated total style loss: 4655967.0
# Style loss for layer block5_conv1: 4741417.5
# Updated total style loss: 6236439.5
# CPU times: user 204206 µs, sys: 204206781 ns, total: 204207 µs
# Wall time: 203552.25 µs
# Iteration: 87
# Total Loss: 6.236505e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1474561.0
# Updated total style loss: 491520.34375
# Style loss for layer block3_conv1: 12318300.0
# Updated total style loss: 4597620.5
# Style loss for layer block5_conv1: 4712105.0
# Updated total style loss: 6168322.0
# CPU times: user 197134 µs, sys: 197134602 ns, total: 197135 µs
# Wall time: 197077.99 µs
# Iteration: 88
# Total Loss: 6.168388e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1466489.5
# Updated total style loss: 488829.84375
# Style loss for layer block3_conv1: 12157132.0
# Updated total style loss: 4541207.5
# Style loss for layer block5_conv1: 4683316.5
# Updated total style loss: 6102313.0
# CPU times: user 201500 µs, sys: 201500011 ns, total: 201501 µs
# Wall time: 205355.41 µs
# Iteration: 89
# Total Loss: 6.102378e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1458513.5
# Updated total style loss: 486171.1875
# Style loss for layer block3_conv1: 11999390.0
# Updated total style loss: 4485968.0
# Style loss for layer block5_conv1: 4655794.0
# Updated total style loss: 6037899.5
# CPU times: user 214895 µs, sys: 214895003 ns, total: 214896 µs
# Wall time: 214354.52 µs
# Iteration: 90
# Total Loss: 6.037965e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1450632.625
# Updated total style loss: 483544.21875
# Style loss for layer block3_conv1: 11844342.0
# Updated total style loss: 4431658.0
# Style loss for layer block5_conv1: 4629948.0
# Updated total style loss: 5974974.0
# CPU times: user 206808 µs, sys: 206808584 ns, total: 206809 µs
# Wall time: 206569.91 µs
# Iteration: 91
# Total Loss: 5.975040e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1442838.75
# Updated total style loss: 480946.25
# Style loss for layer block3_conv1: 11692954.0
# Updated total style loss: 4378598.0
# Style loss for layer block5_conv1: 4606503.5
# Updated total style loss: 5914099.0
# CPU times: user 198063 µs, sys: 198063354 ns, total: 198064 µs
# Wall time: 197880.51 µs
# Iteration: 92
# Total Loss: 5.914165e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1435144.125
# Updated total style loss: 478381.375
# Style loss for layer block3_conv1: 11545961.0
# Updated total style loss: 4327035.0
# Style loss for layer block5_conv1: 4583815.5
# Updated total style loss: 5854973.5
# CPU times: user 202187 µs, sys: 202187321 ns, total: 202188 µs
# Wall time: 201704.98 µs
# Iteration: 93
# Total Loss: 5.855039e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1427552.5
# Updated total style loss: 475850.84375
# Style loss for layer block3_conv1: 11404566.0
# Updated total style loss: 4277373.0
# Style loss for layer block5_conv1: 4560366.5
# Updated total style loss: 5797495.0
# CPU times: user 194489 µs, sys: 194489172 ns, total: 194490 µs
# Wall time: 193761.11 µs
# Iteration: 94
# Total Loss: 5.797561e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1420053.0
# Updated total style loss: 473351.0
# Style loss for layer block3_conv1: 11268654.0
# Updated total style loss: 4229569.0
# Style loss for layer block5_conv1: 4535552.0
# Updated total style loss: 5741420.0
# CPU times: user 204982 µs, sys: 204982091 ns, total: 204983 µs
# Wall time: 204327.34 µs
# Iteration: 95
# Total Loss: 5.741486e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1412649.25
# Updated total style loss: 470883.09375
# Style loss for layer block3_conv1: 11136311.0
# Updated total style loss: 4182986.75
# Style loss for layer block5_conv1: 4510741.0
# Updated total style loss: 5686567.0
# CPU times: user 205105 µs, sys: 205105005 ns, total: 205106 µs
# Wall time: 205304.15 µs
# Iteration: 96
# Total Loss: 5.686633e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1405340.625
# Updated total style loss: 468446.875
# Style loss for layer block3_conv1: 11006543.0
# Updated total style loss: 4137294.5
# Style loss for layer block5_conv1: 4486049.5
# Updated total style loss: 5632644.5
# CPU times: user 198133 µs, sys: 198133244 ns, total: 198134 µs
# Wall time: 197482.82 µs
# Iteration: 97
# Total Loss: 5.632711e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1398122.375
# Updated total style loss: 466040.8125
# Style loss for layer block3_conv1: 10881468.0
# Updated total style loss: 4093196.75
# Style loss for layer block5_conv1: 4462618.0
# Updated total style loss: 5580736.0
# CPU times: user 208623 µs, sys: 208623093 ns, total: 208624 µs
# Wall time: 208593.85 µs
# Iteration: 98
# Total Loss: 5.580802e+09
# --------------------------------------------------------
# Style loss for layer block1_conv1: 1390992.25
# Updated total style loss: 463664.09375
# Style loss for layer block3_conv1: 10759786.0
# Updated total style loss: 4050259.5
# Style loss for layer block5_conv1: 4439098.0
# Updated total style loss: 5529959.0
# CPU times: user 264348 µs, sys: 264348272 ns, total: 264349 µs
# Wall time: 266201.97 µs
# Iteration: 99
# Total Loss: 5.530025e+09
# --------------------------------------------------------

# %%
plt.figure(figsize=(12, 12))  # Set the figure size

# Loop through to plot last 12 generated images in a 4x3 grid (4 rows, 3 columns)
for i in range(12):
    plt.subplot(4, 3, i + 1)  # Create subplots for 4 rows and 3 columns
    display_image(generated_images[i + 87])  # Display image from the 87th index onwards

# Show all the subplots at once
plt.show()

# %%
# plot best result
display_image(final_img)

# %% [markdown]
# ## Examples for Testing

# %% [markdown]
# ![alt text](<Style Transfer Examples-1.png>)
